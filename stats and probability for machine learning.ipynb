# %%
#what is data
'''
categories of data
what us statistics?
basic termilogies in statistics
sampling techniques
types of statistics
descriptive statistics
probablity
inferntial statistics



'''

# %%
'''
what is data?
data refers to facts and statistics collected together for referece or analysis.

categories of data
qualitative(Nominal/ordinal) and quantitative(discrete/continuou)

qualitative data

qualitative data deals with characteristics and descriptors that cant be easily measured , but can be observed subjectly


nominal data

data with no inhert order or ranking such as gender or race , suck kinf of data is called nominal data
eg gender (Male,Felmale)

ordinal Data
data with an ordered series , such as shown in the table suck kind of data is called ordinal data

customer ID and rating
001               Good
002               Average
003               Average
004                Bad



Quantitative Data

quantitative data deals with numbers and things you can measure objectively


Discerte Data 
also known as categorical data, it can hold finite number of possible values
example :number of students in a class

continuous Data
Data  that can hold infinite number of possible values
example weight of a person





'''

# %%
'''
what us statistics
stats is an area applied mathematics concerned with the data collection , analysis , interpretation and presentation


Q your company has created a new drug that may cure cancer . how would you conduct a test to confirm the drug's effectivenes?

Q) the latest sales data have just come in
and your boss wants you to prepare a report for management on places where the 
company could imporve its business, what should you look for?
what should you not look for?




Statistics Terminologies

Population(subject):Acollection or set of indiviuals or objects or events whose properties are to be analyzed


sample: A subset of population is called'sample' a well coosen sample will contain most of the information
and a particular population parameter



sampling techniques

                sampling 
probability                non probability
1.random
2. stratified : 

statum is a subset of the population that shares at least one commom
characteristics (Male , female), in this cas, its gender
random sampling is use to select a sufficient number of subjests from each stratum

3.systematic


Non-probability
snowball 
quota
judgement
convenience




probability




'''

# %%
'''
Types of statistics
1.descriptive statistics :
uses the data to provide descriptions of populations eithere through numerical
calculatuions or graphs or tables
max , avg minimum

descriptive stats is mainly focusesupon the main charactersistcs of sata
it provides graphical summary of the data





2. inferential stats:
inferential statistics makes inferences and predictions about a population 
based on a sample of data taken from the population in question

large
medium
small


inferential statistcs generalises a large dataset and applies probability to
to draw a conclusion. it allows us to infer data parameters based on a statistical 
model using a sample data





'''

# %%
'''Descriptive statistics

Descriptive statistics is a method used to describe and understand the feature of a specific
data set by giving short summaries about the sample and measures of the data

descriptive statistics are broken down into two categories:
meassures of central tendency
measure of variablility (spread)


Measure of Centre
mean:measure of all the values in a sample is called mean



median :  measure of the central value of the sample set (arrange in accending or decending then tke middle or avg of two middle values)

mode: the valye most recurrent in the sample set is known as Mode

measure of variablilty(spread)


measure of spread:sometimes called measure of dispersion , 
used to describe the variablity in a sample or population


range : range is the fiven measure of how spread apart the values in a dataset are.



range =Max(x1)-Min(x2)



inter quartile range :
quartiles tell us about the spread of a data set by breaking the data set into quarters,
just like the median breaks it in half.



inter quartile range(IQR) is the measure of variablility bases on diving a dataset into 
quartiles
quartiles divide a rank ordered data set into four equal parts denoted by q1,q2,q3
the interquartile range is equal to q3 -q1





variance : describes how much a random variable differs from its expected value 


standard deviation :difference between each element of square deviations
measure of the dispersion of a set of data from its mean




population variance is the avg squre of deviation
sample variance  is the avg of square deviation from the mean


sample variance




'''
# Out:
# 'Descriptive statistics\n\nDescriptive statistics is a method used to describe and understand the feature of a specific\ndata set by giving short summaries about the sample and measures of the data\n\ndescriptive statistics are broken down into two categories:\nmeassures of central tendency\nmeasure of variablility (spread)\n\n\n\n\n\n'

# %%
#Information Gain and Entropy

'''
entropy and information  gain (IG)


Entropy

entropy measures the impurity or uncertainty present in the data

where:
s -set of all instances in the dataset
N number of distinct class values
pi event probability



Information gain 
IG indicates how much "information" a particluar feature variable givs usabout
the final outcome





'''

# %%
#the variable with highteat IG is used to split the data at the root node

# %%
# confusion matrix
'''
a confusion matrix is a table that is often used to describe the performance of a classification model on aset of test data for which the true values are know
represents a tabluar reperesentatuon of actual vs predicted values 
(True Positive+True Negatives)/(True positives +true Negatives +false positives +false negatives)

true positive: cases whuch we predicted yes and they do have disease

true negative : cases which we predicted no and they do not have disease

false positive(type 1 error): cases which we predcited yes but they dont have actully disease

false negative (type 2 error) cases which we predicted no but have disease


'''

# %%
# probability
'''
mathematical method for staistical analysis
interconnected branches of mathematics that deals with analyzinf the relative frequency of events


probability is the measure of how likey an event will occur
probability is the ratio of desired outcomes to total outcomes:
(desired outcomes)/(total outcomes)
probability of all outcomes always sums to 1

Terminology in probability

random experiment
sample space
event

types of events 
disjoints events  n(A) ,a(B)


non-disjoints eventsa


'''

# %%
#Probability Distribution
'''
1.probability Density Function
2. normal Distribution
3. central limit theorem






probability Density Function (bell curve): the equation describing a continous probability distribution 
is called a probability Density Function
- continues


normal distribution: a probablity distribution that associates the normal random variable X with a cumulative probability
x =normal random variable
mean
and standard deviation
standard devation and curve

the graph of the distribution depends on two factors: mean and the standard deviation
mean : determines the location of centre of the graph
standard deviation : determines the height of the graph

 if standard deviation is large , the curve is short and wide
 if standarddeviation is small , the curve is tall and narrow
 
'''

# %%
'''
Central limit theorem

the central limit theorem states that tha sampling distribution of the means of any independent, random variable will be
normal or nearly normal, if sample size is large enough

 


'''

# %%
'''
types of probablity
1. marginal probablity: the probability of occurance of a single event

2.joint probability : measure of two events happening at the same time

3.conditional probability
-probabilty of an event or outcome based on the coccurence of a previous event or outcoe
-conditional probablity of an even B id the probablilty that the even will occurs= given that an event A has already occurred
a)  if A and B are dependent events thent he expression for conditional probabilty is given by:
P(B/A) =P(A and B)/P(A)

b) if A and B are independent events then the expression for conditionalprobablilty is given by
p(B/A)=P(B)



'''
